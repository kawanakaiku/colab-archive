# %% [markdown]
# #準備
# 3~4分ほどかかります。

# %% [markdown]
# ##ライブラリのインストール

# %%
# !pip install -q espnet==0.10.3 pyopenjtalk==0.2.0 parallel_wavegan==0.5.3 espnet_model_zoo imgaug==0.2.6
# Out:
#      |████████████████████████████████| 907 kB 36.8 MB/s
#      |████████████████████████████████| 1.5 MB 56.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 68 kB 6.7 MB/s
#      |████████████████████████████████| 631 kB 61.6 MB/s
#      |████████████████████████████████| 73 kB 2.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 1.3 MB 54.1 MB/s
#      |████████████████████████████████| 86 kB 6.2 MB/s
#      |████████████████████████████████| 212 kB 70.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 1.9 MB 55.5 MB/s
#      |████████████████████████████████| 174 kB 64.2 MB/s
# ...

# %%
def increase_font():
  from IPython.display import Javascript
  display(Javascript('''
  for (rule of document.styleSheets[0].cssRules){
    if (rule.selectorText=='body') {
      rule.style.fontSize = '30px'
      break
    }
  }
  '''))

# %% [markdown]
# ##必要ファイルダウンロード

# %%
#amitaro model file
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1rLWz91jcAdvj5BySIGePD7x7Qv_3bCG4" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1rLWz91jcAdvj5BySIGePD7x7Qv_3bCG4' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1rLWz91jcAdvj5BySIGePD7x7Qv_3bCG4" \
-O AMITARO_VITS_accent_with_pause.pth && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1rLWz91jcAdvj5BySIGePD7x7Qv_3bCG4
# To: /content/AMITARO_VITS_accent_with_pause.pth
# 100%|██████████| 373M/373M [00:03<00:00, 109MB/s]

# %%
#amitaro config.yaml
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1YPaUoJ_fP_O0R9LMCGUdKt3-3NSGv1mu" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1YPaUoJ_fP_O0R9LMCGUdKt3-3NSGv1mu' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1YPaUoJ_fP_O0R9LMCGUdKt3-3NSGv1mu" \
-O config_amitaro_vits.yaml && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1YPaUoJ_fP_O0R9LMCGUdKt3-3NSGv1mu
# To: /content/config_amitaro_vits.yaml
# 100%|██████████| 8.34k/8.34k [00:00<00:00, 12.2MB/s]

# %%
#shigure model file
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1YEam6NPjXcbA8ZKgfu1tLoWPhUo26I-O" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1YEam6NPjXcbA8ZKgfu1tLoWPhUo26I-O' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1YEam6NPjXcbA8ZKgfu1tLoWPhUo26I-O" \
-O SHIGURE_VITS_accent_with_pause.pth && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1YEam6NPjXcbA8ZKgfu1tLoWPhUo26I-O
# To: /content/SHIGURE_VITS_accent_with_pause.pth
# 100%|██████████| 373M/373M [00:01<00:00, 194MB/s]

# %%
#shigure config.yaml
# %%bash
gdown "https://drive.google.com/uc?export=download&id=10MErbFTDTgFDpvYqQkI6c8-4Q7OCR0ae" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=10MErbFTDTgFDpvYqQkI6c8-4Q7OCR0ae' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=10MErbFTDTgFDpvYqQkI6c8-4Q7OCR0ae" \
-O config_shigure_vits.yaml && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=10MErbFTDTgFDpvYqQkI6c8-4Q7OCR0ae
# To: /content/config_shigure_vits.yaml
# 100%|██████████| 8.36k/8.36k [00:00<00:00, 12.3MB/s]

# %%
#hakutii model file
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1DVCaqlmMPS8N_2MfkXEGaDZCnhUDKJVJ" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1DVCaqlmMPS8N_2MfkXEGaDZCnhUDKJVJ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1DVCaqlmMPS8N_2MfkXEGaDZCnhUDKJVJ" \
-O HAKUTII_VITS_accent_with_pause.pth && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1DVCaqlmMPS8N_2MfkXEGaDZCnhUDKJVJ
# To: /content/HAKUTII_VITS_accent_with_pause.pth
# 100%|██████████| 373M/373M [00:02<00:00, 151MB/s]

# %%
#hakutii config.yaml
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1-u2g0JNdzdVHNm1F_9854_utlgOsAkBC" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1-u2g0JNdzdVHNm1F_9854_utlgOsAkBC' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-u2g0JNdzdVHNm1F_9854_utlgOsAkBC" \
-O config_hakutii_vits.yaml && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1-u2g0JNdzdVHNm1F_9854_utlgOsAkBC
# To: /content/config_hakutii_vits.yaml
# 100%|██████████| 8.37k/8.37k [00:00<00:00, 10.3MB/s]

# %%
#minelaru model
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1e7zw0_EZ9l2KzZE-wXcx8uol7tGMx0i2" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1e7zw0_EZ9l2KzZE-wXcx8uol7tGMx0i2' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1e7zw0_EZ9l2KzZE-wXcx8uol7tGMx0i2" \
-O MINELARU_VITS_accent_with_pause.pth && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1e7zw0_EZ9l2KzZE-wXcx8uol7tGMx0i2
# To: /content/MINELARU_VITS_accent_with_pause.pth
# 100%|██████████| 373M/373M [00:08<00:00, 43.2MB/s]

# %%
# minelaru config
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1R6aWQmFdR_tg6j0AmMj-2vEGPoHHPeVc" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1R6aWQmFdR_tg6j0AmMj-2vEGPoHHPeVc' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1R6aWQmFdR_tg6j0AmMj-2vEGPoHHPeVc" \
-O config_minelaru_vits.yaml && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1R6aWQmFdR_tg6j0AmMj-2vEGPoHHPeVc
# To: /content/config_minelaru_vits.yaml
# 100%|██████████| 8.17k/8.17k [00:00<00:00, 14.2MB/s]

# %%
# amitaro v2 model
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1gXIW-3cBuyIbP2SBcRVJGCpszDqHbMdQ" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1gXIW-3cBuyIbP2SBcRVJGCpszDqHbMdQ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1gXIW-3cBuyIbP2SBcRVJGCpszDqHbMdQ" \
-O AMITARO_VITS_accent_with_pause_V2_by_2dimlover.pth && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1gXIW-3cBuyIbP2SBcRVJGCpszDqHbMdQ
# To: /content/AMITARO_VITS_accent_with_pause_V2_by_2dimlover.pth
# 100%|██████████| 373M/373M [00:01<00:00, 209MB/s]

# %%
# amitaro v2 config
# %%bash
gdown "https://drive.google.com/uc?export=download&id=1RCGluCNUxu3xPsv7d0d5OcQgE9OeQV9S" || \
wget --load-cookies /tmp/cookies.txt "https://drive.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/uc?export=download&id=1RCGluCNUxu3xPsv7d0d5OcQgE9OeQV9S' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1RCGluCNUxu3xPsv7d0d5OcQgE9OeQV9S" \
-O config_amitaro_vits_v2.yaml && rm -rf /tmp/cookies.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1RCGluCNUxu3xPsv7d0d5OcQgE9OeQV9S
# To: /content/config_amitaro_vits_v2.yaml
# 100%|██████████| 7.39k/7.39k [00:00<00:00, 12.7MB/s]

# %%
#Prosodic_text_tts
#!gdown "https://drive.google.com/uc?export=download&id=1sicMarckeNt2htOBOfvFUV18pjaDtStD"
#!unzip Prosodic_text_tts.zip
#!rm Prosodic_text_tts.zip

# %% [markdown]
# ##モデル読み込み

# %%
# AMITARO model
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

AMITARO = Text2Speech.from_pretrained(
    model_file="AMITARO_VITS_accent_with_pause.pth",
    train_config="config_amitaro_vits.yaml",
    device="cuda",
    speed_control_alpha=1.0,
    noise_scale=0.333,
    noise_scale_dur=0.333,
)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /usr/local/lib/python3.7/dist-packages/espnet2/gan_tts/vits/monotonic_align/__init__.py:22: UserWarning: Cython version is not available. Fallback to 'EXPERIMETAL' numba version. If you want to use the cython version, please build it as follows: `cd espnet2/gan_tts/vits/monotonic_align; python setup.py build_ext --inplace`
#   "Cython version is not available. Fallback to 'EXPERIMETAL' numba version. "

# %%
# SHIGURE model
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

SHIGURE = Text2Speech.from_pretrained(
    model_file="SHIGURE_VITS_accent_with_pause.pth",
    train_config="config_shigure_vits.yaml",
    device="cuda",
    speed_control_alpha=1.0,
    noise_scale=0.333,
    noise_scale_dur=0.333,
)

# %%
# HAKUTII model
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

HAKUTII = Text2Speech.from_pretrained(
    model_file="HAKUTII_VITS_accent_with_pause.pth",
    train_config="config_hakutii_vits.yaml",
    device="cuda",
    speed_control_alpha=1.0,
    noise_scale=0.333,
    noise_scale_dur=0.333,
)

# %%
# MINELARU model
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

MINELARU = Text2Speech.from_pretrained(
    model_file="MINELARU_VITS_accent_with_pause.pth",
    train_config="config_minelaru_vits.yaml",
    device="cuda",
    speed_control_alpha=1.0,
    noise_scale=0.333,
    noise_scale_dur=0.333,
)

# %%
# AMITARO v2 model
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

AMITARO_v2 = Text2Speech.from_pretrained(
    model_file="AMITARO_VITS_accent_with_pause_V2_by_2dimlover.pth",
    train_config="config_amitaro_vits_v2.yaml",
    device="cuda",
    speed_control_alpha=1.0,
    noise_scale=0.333,
    noise_scale_dur=0.333,
)

# %% [markdown]
# ##その他

# %%
from espnet2.text.token_id_converter import TokenIDConverter
import yaml
with open("./config_amitaro_vits.yaml") as file:
    yamldata = yaml.safe_load(file)
print(yamldata)
token_id_converter1 = TokenIDConverter(
            token_list=yamldata["token_list"],
            unk_symbol="<unk>",
            )

with open("./config_minelaru_vits.yaml") as file:
    yamldata = yaml.safe_load(file)
token_id_converter2 = TokenIDConverter(
            token_list=yamldata["token_list"],
            unk_symbol="<unk>",
            )
# Out:
# {'config': './conf/tuning/finetune_full_band_vits.yaml', 'print_config': False, 'log_level': 'INFO', 'dry_run': False, 'iterator_type': 'sequence', 'output_dir': 'exp/tts_AMITARO_full_band_vits', 'ngpu': 1, 'seed': 777, 'num_workers': 128, 'num_att_plot': 3, 'dist_backend': 'nccl', 'dist_init_method': 'env://', 'dist_world_size': None, 'dist_rank': None, 'local_rank': 0, 'dist_master_addr': None, 'dist_master_port': None, 'dist_launcher': None, 'multiprocessing_distributed': False, 'unused_parameters': True, 'sharded_ddp': False, 'cudnn_enabled': True, 'cudnn_benchmark': False, 'cudnn_deterministic': False, 'collect_stats': False, 'write_collected_feats': False, 'max_epoch': 100, 'patience': None, 'val_scheduler_criterion': ['valid', 'loss'], 'early_stopping_criterion': ['valid', 'loss', 'min'], 'best_model_criterion': [['train', 'total_count', 'max']], 'keep_nbest_models': 10, 'grad_clip': -1, 'grad_clip_type': 2.0, 'grad_noise': False, 'accum_grad': 1, 'no_forward_run': False, 'res
# ...

# %%
#!/usr/bin/env python3

import numpy as np
import re
import pyopenjtalk
import jaconv

#各条件を正規表現で表す
c1 = '[ウクスツヌフムユルグズヅブプヴ][ァィェォ]' #ウ段＋「ァ/ィ/ェ/ォ」
c2 = '[イキシチニヒミリギジヂビピ][ャュェョ]' #イ段（「イ」を除く）＋「ャ/ュ/ェ/ョ」
c3 = '[テデ][ィュ]' #「テ/デ」＋「ャ/ィ/ュ/ョ」
c4 = '[ァ-ヴー^＾,.、。？！!?]' #カタカナ１文字（長音含む）

cond = '('+c1+'|'+c2+'|'+c3+'|'+c4+')'
re_mora = re.compile(cond)

def moraWakachi(kana_text):
    return re_mora.findall(kana_text)

def accent_phrase(text):
    import pyopenjtalk
    import re
    

    phones = []
    prev=-1
    phrase_len=[]
    accent_idx=[]
    kata=pyopenjtalk.g2p(text,kana=True)
    
    mora = moraWakachi(kata)
    for labels in pyopenjtalk.run_frontend(text)[1]:
        if labels.split("-")[1].split("+")[0] == "pau":
            phrase_len.append("null")
            accent_idx.append("null")
            continue
        p = re.findall(r"F:([0-9]+)_([0-9]+).*?@([0-9]+)_", labels)
        if len(p) == 1:
            if prev != p[0][2] :
                phrase_len.append(int(p[0][0]))
                accent_idx.append(int(p[0][1]))
            prev=p[0][2]
    left=0
    phrase=[]
    for idx in phrase_len:
        if idx != "null":
            phrase += [mora[left:left+idx]]
            left+=idx
        else :
            phrase += [''.join(mora[left:left+1])]
            left+=1
    
    return phrase,phrase_len,accent_idx

def text2yomi(text):
    accented=""
    ap=accent_phrase(text)
    for i,phrase_mora in enumerate(ap[0]):
        if ap[1][i] == "null":
            accented += ''.join(phrase_mora)
            accented+=" "
        else:
            phrase = phrase_mora[:ap[2][i]]
            phrase += '^'
            phrase += phrase_mora[ap[2][i]:]

            accented+=''.join(phrase)
            accented+=" "
    
    yomi = jaconv.kata2hira(accented[0:-1])
    
    return yomi

def a2p(accented):
    phonemes = np.empty(0)
    #print("アクセント句分割：")
    #print(accented.split('　'))
    #print("\n")
    for phrase in accented.split('　'):
        
        mora = moraWakachi( jaconv.hira2kata(phrase) )

        if '^' in mora : 
            nucleus = mora.index('^')
            mora.remove('^')
            plane_text = phrase.replace('^','')
        elif '＾' in mora :
            nucleus = mora.index('＾')
            mora.remove('＾')
            plane_text = phrase.replace('＾','')
        else : 
            phonemes = np.append(phonemes,'pau')
            continue

        n_mora = len(mora)

        distances = np.arange(1,n_mora+1) - nucleus
        distances = distances.reshape(-1,1)

        nucleuses = np.array(nucleus)
        nucleuses = np.tile(nucleuses , (n_mora,1))

        nuc_dist=np.hstack([nucleuses , distances])
        #print(nuc_dist)
    
        phrase_phonemes = np.empty(0)
        mora_idx = np.empty(0)
        prev_idx=0
        i = 0
        #print("モーラ分割：")
        #print(mora)
        #print("\n")
        
        #print("音素 , アクセント核の位置(モーラ単位) , アクセント核からの距離(モーラ単位)：")
        for labels in pyopenjtalk.run_frontend(plane_text)[1]:
            if labels.split("-")[1].split("+")[0] == "pau":
                continue
            p = re.findall(r"\-(.*?)\+.*?\/A:[0-9\-]+\+([0-9\-]+)", labels)
            if len(p) == 1:
                #print(p[0][0] , end=' , ')
                phrase_phonemes = np.append(phrase_phonemes , p[0][0])
                idx = int(p[0][1]) - 1
                if idx != prev_idx :
                    i += 1
                    prev_idx = idx
                #print(nuc_dist[i])
                
                phrase_phonemes = np.append(phrase_phonemes , nuc_dist[i])
                
        #print("\n")
        phonemes = np.append(phonemes , phrase_phonemes)
        #print(phonemes)
    return phonemes

# %% [markdown]
# #<font size=7>音声合成</font>
# <b><font size=6 color='Red'>このモデルで合成された音声は商用利用不可です。ご注意ください。</font></b>

# %%
#@title 左の再生ボタンを押すと音声合成されます{run:"auto"}
increase_font()
import torch
import pyopenjtalk
from espnet2.bin.tts_inference import Text2Speech
from espnet2.tasks.tts import TTSTask
import numpy as np

character=AMITARO_v2 #@param ["AMITARO","SHIGURE","HAKUTII","MINELARU","AMITARO_v2"] {type:"raw"}
speed = 1 #@param {type:"slider", min:0.1, max:2, step:0.1}
noise_scale = 0.33 #@param {type:"slider", min:0.1, max:1, step:0.01}
noise_scale_dur = 0.33 #@param {type:"slider", min:0.1, max:1, step:0.01}
text = "\u3053\u3093\u306B\u3061\u306F\u3001\u3042\u307F\u305F\u308D\u3067\u3059\u3002\u30AD\u30E3\u30E9\u30AF\u30BF\u30FC\u306E\u3068\u3053\u308D\u3067\u3001\u6642\u96E8\u3055\u3093\u3084\u3001\u30CF\u30AF\u30C1\u30FC\u3055\u3093\u3001\u30DF\u30CD\u30E9\u30EB\u3055\u3093\u304C\u9078\u3079\u307E\u3059\u3088\u3002" #@param {type:"string"}

accent_text = "\u3053\u3093\u306B\u3061\u306F\uFF3E\u3000\u3001\u3000\u3042\u307F\uFF3E\u305F\u308D\u3067\u3059\u3000\u3001\u3000\u304D\u3083\u3089\u304F\u305F\u30FC\u306E\uFF3E\u3000\u3068\u3053\u308D\uFF3E\u3067\u3000\u3001\u3000\u3057\u3050\u308C\u3055\u3093\u3084\uFF3E\u3000\u3001\u3000\uFF3E\u30CF\u30AF\u30C1\u30FC\u3000\uFF3E\u3055\u3093\u3000\u3001\u3000\u307F\uFF3E\u306D\u3089\u308B\u3055\u3093\u304C\u3000\u3048\u3089\u3079\u307E\uFF3E\u3059\u3088" #@param {type:"string"}
#@markdown 「accent_text」の書き方は[こちら](https://qiita.com/seichi25/items/bb79f66d3eaa6a605c74)をご参照ください。   
#@markdown #クレジット<br>
#@markdown <b>事前学習データセット :</b> https://sites.google.com/site/shinnosuketakamichi/publication/jsut</b><br>
#@markdown <b>事前学習モデル : </b>https://huggingface.co/espnet/kan-bayashi_jsut_full_band_vits_accent_with_pause<br>
#@markdown <b>音声合成ツールキット : ESPNet</b> https://github.com/espnet/espnet
#@markdown <br><b>ファインチューニングデータセット</b><br>
#@markdown <b>AMITARO : </b>あみたろの声素材工房 ITAコーパス読み上げ音声　https://amitaro.net/voice/ita/　twitter:@amitaro_utau<br>
#@markdown <b>SHIGURE : </b>刻鳴時雨ITAコーパス読み上げ音声素材　https://bindume-chan.booth.pm/items/3640133 twitter:@Tokina_Shigure<br>
#@markdown <b>HAKUTII : </b>ITAコーパス読み上げ音声配布〈CoeFont解説〉https://www.nicovideo.jp/watch/sm40049556 twitter:@hakuti892<br>
#@markdown <b>MINELARU : </b>ITAコーパスを録ったので、配布します。...　https://twitter.com/M_C3O2/status/1495744409505505281 twitter:@M_C3O2<br>
#@markdown <b>AMITARO_v2 : </b>あみたろの声素材工房 ITAコーパス読み上げ音声　https://amitaro.net/voice/ita/　twitter:@amitaro_utau<br>
#@markdown <br><b>AMITARO_2 モデル提供者：</b>アコギミン　twitter:@2dimlover
#@markdown <br><b>その他モデル学習処理：</b>seichi twitter:@seichi25

#decod_conf set
character.decode_conf.update({'alpha':2.1-speed,
                              'noise_scale':noise_scale,
                              'noise_scale_dur':noise_scale_dur})
#accent processing
tokens = a2p(accent_text)
if character == MINELARU:
    text_ints = token_id_converter2.tokens2ids(tokens)
else:
    text_ints = token_id_converter1.tokens2ids(tokens)
int_tensor = np.array(text_ints)

with torch.no_grad():
    wav1 = character(text)["wav"]
    wav2 = character(int_tensor)["wav"]


# let us listen to generated samples
from IPython.display import display, Audio
print(text)
display(Audio(wav1.view(-1).cpu().numpy(), rate=44100))
print(accent_text)
display(Audio(wav2.view(-1).cpu().numpy(), rate=44100))
# Out:
# Downloading: "https://github.com/r9y9/open_jtalk/releases/download/v1.11.1/open_jtalk_dic_utf_8-1.11.tar.gz"
# dic.tar.gz: 0.00B [00:00, ?B/s]
# Extracting tar file /usr/local/lib/python3.7/dist-packages/pyopenjtalk/dic.tar.gz
# こんにちは、あみたろです。キャラクターのところで、時雨さんや、ハクチーさん、ミネラルさんが選べますよ。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# こんにちは＾　、　あみ＾たろです　、　きゃらくたーの＾　ところ＾で　、　しぐれさんや＾　、　＾ハクチー　＾さん　、　み＾ねらるさんが　えらべま＾すよ
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
